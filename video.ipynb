# %%
import os
from ultralytics import YOLO
import torch
import cv2
from tqdm import tqdm
import pyttsx3
import numpy as np
import time

# %%
model = YOLO("D:\\Documents\\pythonProjectLabelimg\\yolo_dataset\\res\\yolov8n_fold_3_BEST\\weights\\best.pt")

# %%
engine = pyttsx3.init()
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)
engine.setProperty('rate', 150)

# %%
def speak(text):
    engine.say(text)
    engine.runAndWait()

# %%
def calculate_iou(box1, box2):
    #box1: (x1, y1, x2, y2) - bounding box
    #box2: (x1, y1, x2, y2) - основной прямоугольник
    x1_intersect = max(box1[0], box2[0])
    y1_intersect = max(box1[1], box2[1])
    x2_intersect = min(box1[2], box2[2])
    y2_intersect = min(box1[3], box2[3])

    intersection_area = max(0, x2_intersect - x1_intersect) * max(0, y2_intersect - y1_intersect)
    square = abs(box1[2]-box1[0])*abs(box1[3]-box1[1])

    return intersection_area/square

# %%
video_path = "D:\\Documents\\pythonProjectLabelimg\\yolo_dataset\\video\\video_2025-04-27_18-31-56.mp4" 
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("Ошибка при открытии видеофайла")
    exit()

# FPS и размеры видео
frame_width = int(cap.get(3))
frame_height = int(cap.get(4))
fps = cap.get(cv2.CAP_PROP_FPS)

rect_width = 550
rect_height = 1100
roi_x1 = (frame_width - rect_width) // 2 
roi_y1 = (frame_height - rect_height) // 2 + 100
color = (0, 255, 0)
thickness = 2 

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
output_path = "D:\\Documents\\pythonProjectLabelimg\\yolo_dataset\\res\\videos\\video_1.mp4"
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

spoken_objects = {}  # словарь для хранения класса последнего объекта
objects = []
cooldown_duration = 8 # задержка для одного класса

while True:
    ret, frame = cap.read()
    if not ret:
        break

    start_time = time.time()

    results = model(frame, stream=True)

    cv2.rectangle(frame, (roi_x1, roi_y1), (roi_x1 + rect_width, roi_y1 + rect_height), color, thickness)#отрисовка ограничевающего прямоугольника
#    print(roi_box)
    cv2.ROTATE_90_CLOCKWISE
    for r in results:
        boxes = r.boxes # bounding boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0] # координаты bounding box
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            w, h = x2 - x1, y2 - y1 # ширина и высота

            conf = box.conf[0] # уверенность
            conf = float(conf)
            if conf >= 0.6:
                roi_box = (roi_x1, roi_y1, roi_x1 + rect_width, roi_y1 + rect_height)
                bbox = (x1, y1, x2, y2)
                square = calculate_iou(bbox, roi_box)
                print(bbox)
                if square >= 0.7:
                    class_id = int(box.cls[0])  #ID класса
                    #classes =  ['car', 'curb', 'door', 'wall', 'ladder', 'down', 'pit', 'hatch', 'fence', 'tram tracks']
                    classes = ['машина', 'бордюр', 'дверь', 'стена', 'лестница', 'спуск', 'яма', 'люк', 'ограждение', 'трамвайные пути']
                    class_name = classes[class_id]
                    print(square, class_name)
                    if class_name not in objects or time.time() - spoken_objects[class_name] >= cooldown_duration:
                        spoken_objects[class_name] = time.time()
                        objects.append(class_name)
                        speak(f"Впереди {class_name}")


                cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 255), 3)
                label = f'{class_name} {conf:.2f}'
                cv2.putText(frame, label, (x1, y1 + 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 0, 255), 2)

    end_time = time.time()
    fps = 1 / (end_time - start_time) # FPS
    cv2.putText(frame, f"FPS: {fps:.2f}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)


    cv2.imshow('YOLOv8 Detections', frame)
    out.write(frame)

    # выход по нажатию 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 2  s, 18.6ms
# Speed: 1357.6ms preprocess, 18.6ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2  s, 13.3ms
# (0, 409, 575, 1280)
# 0.8521739130434782
# Speed: 3.2ms preprocess, 13.3ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2  s, 22.4ms
# (0, 412, 561, 1280)
# 0.8484848484848485
# Speed: 3.7ms preprocess, 22.4ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2  s, 19.1ms
# (0, 399, 492, 1261)
# 0.8272357723577236
# Speed: 3.5ms preprocess, 19.1ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2  s, 18.6ms
# (0, 420, 551, 1280)
# 0.8457350272232305
# Speed: 2.4ms preprocess, 18.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 17.4ms
# (0, 399, 512, 1264)
# 0.833984375
# Speed: 2.4ms preprocess, 17.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2  s, 13.2ms
# (0, 408, 570, 1280)
# 0.8508771929824561
# Speed: 2.3ms preprocess, 13.2ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3  s, 18.1ms
# (0, 422, 586, 1280)
# 0.8549488054607508
# Speed: 2.1ms preprocess, 18.1ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3  s, 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2  s, 15.8ms
# Speed: 3.3ms preprocess, 15.8ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.3ms
# Speed: 2.1ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.8ms
# (0, 420, 563, 1280)
# 0.8490230905861457
# Speed: 3.0ms preprocess, 14.8ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.0ms
# Speed: 2.4ms preprocess, 16.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.7ms
# (4, 419, 515, 1261)
# 0.8414872798434442
# Speed: 2.3ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.9ms
# (0, 413, 553, 1280)
# 0.8462929475587704
# Speed: 2.3ms preprocess, 13.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.6ms
# (0, 414, 561, 1280)
# 0.8484848484848485
# Speed: 2.9ms preprocess, 14.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.4ms
# Speed: 2.2ms preprocess, 13.4ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.8ms
# (0, 413, 559, 1280)
# 0.8479427549194991
# Speed: 2.2ms preprocess, 13.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.4ms
# (0, 414, 560, 1280)
# 0.8482142857142857
# Speed: 2.4ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2  s, 13.5ms
# (0, 414, 580, 1280)
# 0.853448275862069
# Speed: 2.2ms preprocess, 13.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.7ms
# (5, 417, 557, 1261)
# 0.855072463768116
# Speed: 2.1ms preprocess, 14.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.3ms
# (0, 420, 602, 1280)
# 0.8588039867109635
# Speed: 2.1ms preprocess, 15.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.7ms
# (0, 425, 596, 1280)
# 0.8573825503355704
# Speed: 2.3ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.1ms
# (0, 425, 579, 1280)
# 0.853195164075993
# Speed: 3.2ms preprocess, 15.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.7ms
# (0, 426, 586, 1280)
# 0.8549488054607508
# Speed: 2.1ms preprocess, 14.7ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 17.0ms
# (0, 426, 584, 1280)
# 0.8544520547945206
# Speed: 2.4ms preprocess, 17.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.3ms
# Speed: 2.4ms preprocess, 13.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.3ms
# (0, 423, 579, 1280)
# 0.853195164075993
# Speed: 2.1ms preprocess, 13.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.2ms
# Speed: 2.1ms preprocess, 14.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.7ms
# Speed: 2.6ms preprocess, 15.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.6ms
# Speed: 2.1ms preprocess, 13.6ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.0ms
# Speed: 2.3ms preprocess, 15.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.6ms
# (2, 423, 565, 1280)
# 0.8525754884547069
# Speed: 3.9ms preprocess, 13.6ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.7ms
# (2, 423, 561, 1280)
# 0.851520572450805
# Speed: 2.2ms preprocess, 15.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 17.1ms
# (3, 424, 573, 1280)
# 0.856140350877193
# Speed: 3.2ms preprocess, 17.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.2ms
# (2, 424, 574, 1280)
# 0.8548951048951049
# Speed: 2.1ms preprocess, 16.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.6ms
# (1, 424, 578, 1280)
# 0.854419410745234
# Speed: 2.2ms preprocess, 16.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.2ms
# (1, 428, 592, 1280)
# 0.8578680203045685
# Speed: 3.3ms preprocess, 16.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.3ms
# (0, 433, 576, 1280)
# 0.8524305555555556
# Speed: 2.3ms preprocess, 14.3ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.5ms
# (0, 429, 576, 1280)
# 0.8524305555555556
# Speed: 3.0ms preprocess, 15.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.6ms
# (0, 422, 578, 1280)
# 0.8529411764705882
# Speed: 2.1ms preprocess, 13.6ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.9ms
# (0, 420, 581, 1280)
# 0.8537005163511188
# Speed: 2.2ms preprocess, 14.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.4ms
# (0, 419, 582, 1280)
# 0.8539518900343642
# Speed: 2.1ms preprocess, 14.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.4ms
# (0, 419, 561, 1280)
# 0.8484848484848485
# Speed: 2.1ms preprocess, 13.4ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.9ms
# (0, 418, 575, 1280)
# 0.8521739130434782
# Speed: 2.1ms preprocess, 13.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.2ms
# (0, 425, 577, 1280)
# 0.8526863084922011
# Speed: 2.0ms preprocess, 16.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.3ms
# (0, 422, 569, 1280)
# 0.8506151142355008
# Speed: 2.3ms preprocess, 13.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.0ms
# (0, 424, 583, 1280)
# 0.8542024013722127
# Speed: 2.2ms preprocess, 16.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.2ms
# (0, 420, 603, 1280)
# 0.8590381426202321
# Speed: 2.1ms preprocess, 15.2ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 17.5ms
# Speed: 2.5ms preprocess, 17.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.7ms
# Speed: 3.6ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.7ms
# Speed: 2.3ms preprocess, 13.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.6ms
# Speed: 2.9ms preprocess, 16.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.5ms
# Speed: 2.6ms preprocess, 15.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.5ms
# Speed: 3.1ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 17.1ms
# Speed: 3.9ms preprocess, 17.1ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 17.2ms
# Speed: 3.4ms preprocess, 17.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 18.1ms
# Speed: 2.8ms preprocess, 18.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.3ms
# Speed: 3.2ms preprocess, 13.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.0ms
# Speed: 2.6ms preprocess, 15.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 17.9ms
# Speed: 2.8ms preprocess, 17.9ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.3ms
# Speed: 2.5ms preprocess, 16.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.8ms
# Speed: 2.6ms preprocess, 16.8ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 24.2ms
# Speed: 2.7ms preprocess, 24.2ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2  s, 13.4ms
# (0, 396, 592, 1255)
# 0.856418918918919
# Speed: 1.9ms preprocess, 13.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.4ms
# (0, 396, 581, 1257)
# 0.8537005163511188
# Speed: 3.5ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.9ms
# (0, 401, 589, 1258)
# 0.8556876061120543
# Speed: 2.2ms preprocess, 13.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.3ms
# (0, 403, 587, 1257)
# 0.8551959114139693
# Speed: 2.4ms preprocess, 13.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.3ms
# (0, 403, 585, 1255)
# 0.8547008547008547
# Speed: 2.7ms preprocess, 14.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.6ms
# (0, 405, 594, 1257)
# 0.8569023569023569
# Speed: 2.4ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.8ms
# Speed: 2.3ms preprocess, 13.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.2ms
# Speed: 2.3ms preprocess, 16.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.0ms
# Speed: 2.9ms preprocess, 16.0ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.4ms
# Speed: 2.3ms preprocess, 15.4ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 17.4ms
# Speed: 2.3ms preprocess, 17.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.7ms
# Speed: 2.3ms preprocess, 15.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.2ms
# Speed: 1.9ms preprocess, 13.2ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 36.6ms
# Speed: 3.5ms preprocess, 36.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 21.1ms
# Speed: 3.9ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2  s, 16.2ms
# Speed: 2.5ms preprocess, 16.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2  s, 16.1ms
# Speed: 3.1ms preprocess, 16.1ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2  s, 15.6ms
# Speed: 3.8ms preprocess, 15.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.2ms
# Speed: 2.9ms preprocess, 15.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.0ms
# Speed: 2.3ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 17.2ms
# (0, 386, 547, 1252)
# 0.8446069469835467
# Speed: 2.2ms preprocess, 17.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.6ms
# (0, 382, 547, 1259)
# 0.8446069469835467
# Speed: 2.5ms preprocess, 15.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 20.7ms
# (0, 378, 547, 1261)
# 0.8446069469835467
# Speed: 2.1ms preprocess, 20.7ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 17.4ms
# (0, 384, 547, 1260)
# 0.8446069469835467
# Speed: 2.4ms preprocess, 17.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.6ms
# (0, 386, 545, 1259)
# 0.8440366972477065
# Speed: 2.6ms preprocess, 15.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.0ms
# (0, 389, 542, 1257)
# 0.8431734317343174
# Speed: 4.1ms preprocess, 15.0ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.6ms
# (0, 387, 538, 1252)
# 0.8420074349442379
# Speed: 3.2ms preprocess, 13.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.8ms
# (0, 384, 535, 1248)
# 0.8411214953271028
# Speed: 2.4ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.7ms
# (0, 384, 531, 1247)
# 0.839924670433145
# Speed: 2.1ms preprocess, 15.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 32.7ms
# (0, 386, 529, 1247)
# 0.8393194706994329
# Speed: 2.4ms preprocess, 32.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.4ms
# (0, 386, 535, 1246)
# 0.8411214953271028
# Speed: 2.2ms preprocess, 15.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.9ms
# (0, 390, 532, 1243)
# 0.8402255639097744
# Speed: 2.0ms preprocess, 14.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.8ms
# (0, 389, 522, 1242)
# 0.8371647509578544
# Speed: 2.1ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 17.2ms
# (0, 386, 527, 1247)
# 0.8387096774193549
# Speed: 1.9ms preprocess, 17.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.1ms
# (0, 389, 527, 1252)
# 0.8387096774193549
# Speed: 2.2ms preprocess, 15.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.1ms
# (0, 392, 528, 1254)
# 0.8390151515151515
# Speed: 2.3ms preprocess, 14.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 18.6ms
# (0, 393, 528, 1253)
# 0.8390151515151515
# Speed: 2.7ms preprocess, 18.6ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 17.9ms
# (0, 393, 528, 1255)
# 0.8390151515151515
# Speed: 2.6ms preprocess, 17.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.4ms
# (0, 395, 530, 1257)
# 0.839622641509434
# Speed: 3.4ms preprocess, 16.4ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.1ms
# (0, 394, 527, 1259)
# 0.8387096774193549
# Speed: 3.2ms preprocess, 15.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.6ms
# (0, 397, 519, 1254)
# 0.8362235067437379
# Speed: 3.0ms preprocess, 13.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.5ms
# (0, 397, 519, 1258)
# 0.8362235067437379
# Speed: 3.5ms preprocess, 14.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 58.7ms
# (0, 391, 488, 1257)
# 0.8258196721311475
# Speed: 3.3ms preprocess, 58.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 18.2ms
# (0, 394, 531, 1258)
# 0.839924670433145
# Speed: 2.8ms preprocess, 18.2ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 20.6ms
# Speed: 3.2ms preprocess, 20.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 18.5ms
# Speed: 2.7ms preprocess, 18.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.4ms
# Speed: 2.7ms preprocess, 15.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.0ms
# (0, 405, 540, 1254)
# 0.8425925925925926
# Speed: 3.8ms preprocess, 16.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.0ms
# Speed: 2.9ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.2ms
# (1, 395, 538, 1255)
# 0.8435754189944135
# Speed: 2.2ms preprocess, 16.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 39.6ms
# (5, 407, 511, 1258)
# 0.841897233201581
# Speed: 3.1ms preprocess, 39.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.9ms
# (0, 411, 532, 1256)
# 0.8402255639097744
# Speed: 2.0ms preprocess, 14.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.7ms
# (2, 410, 530, 1253)
# 0.8428030303030303
# Speed: 2.1ms preprocess, 15.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.2ms
# (2, 405, 533, 1255)
# 0.8436911487758946
# Speed: 2.0ms preprocess, 13.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 13.7ms
# (2, 418, 532, 1258)
# 0.8433962264150944
# Speed: 1.9ms preprocess, 13.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.2ms
# (1, 423, 529, 1257)
# 0.8409090909090909
# Speed: 2.0ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.6ms
# (1, 423, 524, 1256)
# 0.8393881453154876
# Speed: 2.2ms preprocess, 16.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 16.1ms
# (0, 416, 535, 1280)
# 0.8411214953271028
# Speed: 2.5ms preprocess, 16.1ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.4ms
# (0, 416, 534, 1280)
# 0.8408239700374532
# Speed: 2.4ms preprocess, 14.4ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 17.1ms
# (0, 414, 528, 1257)
# 0.8390151515151515
# Speed: 2.8ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 20.4ms
# (0, 419, 535, 1280)
# 0.8411214953271028
# Speed: 2.1ms preprocess, 20.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 62.5ms
# (0, 419, 538, 1280)
# 0.8420074349442379
# Speed: 2.9ms preprocess, 62.5ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.1ms
# (0, 426, 532, 1280)
# 0.8402255639097744
# Speed: 3.7ms preprocess, 14.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 17.3ms
# (0, 435, 529, 1280)
# 0.8393194706994329
# Speed: 3.1ms preprocess, 17.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.8ms
# (0, 436, 530, 1280)
# 0.839622641509434
# Speed: 4.7ms preprocess, 14.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.2ms
# (0, 445, 526, 1280)
# 0.8384030418250951
# Speed: 2.1ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 14.4ms
# (0, 471, 527, 1279)
# 0.8387096774193549
# Speed: 3.7ms preprocess, 14.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1  , 15.3ms
# Speed: 1.9ms preprocess, 15.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.8ms
# Speed: 2.7ms preprocess, 16.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.3ms
# Speed: 5.8ms preprocess, 15.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 18.8ms
# Speed: 2.6ms preprocess, 18.8ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 54.9ms
# Speed: 2.8ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.7ms
# Speed: 2.1ms preprocess, 13.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.4ms
# Speed: 2.6ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.7ms
# Speed: 1.9ms preprocess, 13.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 18.1ms
# Speed: 2.1ms preprocess, 18.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.7ms
# Speed: 3.1ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 27.2ms
# Speed: 4.5ms preprocess, 27.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 20.3ms
# Speed: 3.0ms preprocess, 20.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 17.9ms
# Speed: 4.5ms preprocess, 17.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 43.7ms
# Speed: 2.3ms preprocess, 43.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 17.3ms
# Speed: 3.4ms preprocess, 17.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.9ms
# Speed: 3.1ms preprocess, 13.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.1ms
# Speed: 2.3ms preprocess, 16.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.6ms
# Speed: 2.2ms preprocess, 16.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.2ms
# Speed: 2.2ms preprocess, 15.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 19.9ms
# Speed: 3.8ms preprocess, 19.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.8ms
# Speed: 3.9ms preprocess, 16.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 70.8ms
# Speed: 3.1ms preprocess, 70.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.5ms
# Speed: 3.1ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.5ms
# Speed: 2.1ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.1ms
# Speed: 2.2ms preprocess, 14.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.7ms
# Speed: 3.1ms preprocess, 14.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.4ms
# Speed: 3.3ms preprocess, 13.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 19.8ms
# Speed: 2.3ms preprocess, 19.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 20.2ms
# Speed: 2.2ms preprocess, 20.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 71.7ms
# Speed: 3.4ms preprocess, 71.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.2ms
# Speed: 2.2ms preprocess, 14.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.9ms
# Speed: 2.1ms preprocess, 13.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.1ms
# Speed: 2.4ms preprocess, 15.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.0ms
# Speed: 2.4ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 17.9ms
# Speed: 2.2ms preprocess, 17.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 19.3ms
# Speed: 3.1ms preprocess, 19.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 17.0ms
# Speed: 5.8ms preprocess, 17.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 43.8ms
# Speed: 3.2ms preprocess, 43.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 13.7ms
# Speed: 2.3ms preprocess, 13.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.0ms
# Speed: 2.4ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.4ms
# Speed: 2.6ms preprocess, 15.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 15.4ms
# Speed: 3.3ms preprocess, 15.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 16.7ms
# Speed: 2.3ms preprocess, 16.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.0ms
# Speed: 3.5ms preprocess, 59.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 19
3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 1 , 17.0ms
# Speed: 2.3ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 1 , 20.1ms
# Speed: 2.5ms preprocess, 20.1ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 1 , 15.7ms
# Speed: 3.3ms preprocess, 15.7ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 27.0ms
# Speed: 2.0ms preprocess, 27.0ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 20.9ms
# Speed: 2.0ms preprocess, 20.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 1 , 17.1ms
# Speed: 2.6ms preprocess, 17.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 15.6ms
# Speed: 2.5ms preprocess, 15.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 16.6ms
# Speed: 2.4ms preprocess, 16.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.8ms
# Speed: 2.3ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 14.0ms
# Speed: 2.6ms preprocess, 14.0ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 16.7ms
# Speed: 3.3ms preprocess, 16.7ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 1 , 37.7ms
# Speed: 2.2ms preprocess, 37.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 29.6ms
# Speed: 3.2ms preprocess, 29.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 21.1ms
# (183, 279, 470, 586)
# 1.0
# Speed: 2.2ms preprocess, 21.1ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 21.2ms
# Speed: 3.7ms preprocess, 21.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 16.5ms
# Speed: 2.5ms preprocess, 16.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 18.8ms
# (201, 282, 494, 589)
# 1.0
# Speed: 3.9ms preprocess, 18.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 19.8ms
# (205, 283, 504, 588)
# 1.0
# Speed: 2.6ms preprocess, 19.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 65.6ms
# (213, 278, 506, 589)
# 1.0
# Speed: 2.6ms preprocess, 65.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 14.2ms
# (221, 272, 513, 590)
# 1.0
# Speed: 3.2ms preprocess, 14.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 15.1ms
# Speed: 1.8ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 14.7ms
# Speed: 3.3ms preprocess, 14.7ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 15.7ms
# (239, 268, 532, 588)
# 1.0
# Speed: 2.2ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 13.2ms
# (241, 269, 542, 588)
# 1.0
# Speed: 3.3ms preprocess, 13.2ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 38.5ms
# (245, 265, 550, 592)
# 1.0
# Speed: 2.5ms preprocess, 38.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 14.3ms
# (247, 267, 554, 590)
# 1.0
# Speed: 2.4ms preprocess, 14.3ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 13.8ms
# (248, 265, 558, 590)
# 1.0
# Speed: 2.7ms preprocess, 13.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 13.5ms
# (248, 269, 567, 590)
# 1.0
# Speed: 3.9ms preprocess, 13.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 15.3ms
# (256, 274, 570, 591)
# 1.0
# Speed: 2.1ms preprocess, 15.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 15.1ms
# (261, 271, 576, 591)
# 1.0
# Speed: 2.2ms preprocess, 15.1ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 16.3ms
# (268, 266, 580, 596)
# 1.0
# Speed: 2.4ms preprocess, 16.3ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 15.8ms
# (274, 268, 586, 595)
# 1.0
# Speed: 4.3ms preprocess, 15.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 14.9ms
# (284, 266, 590, 596)
# 1.0
# Speed: 2.1ms preprocess, 14.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 15.9ms
# (289, 262, 592, 595)
# 1.0
# Speed: 1.9ms preprocess, 15.9ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 17.3ms
# (292, 252, 599, 597)
# 1.0
# Speed: 2.0ms preprocess, 17.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 , 14.6ms
# (295, 250, 610, 598)
# 1.0
# Speed: 2.0ms preprocess, 14.6ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 40
#      38 #    print(roi_box)
#      39     cv2.ROTATE_90_CLOCKWISE
# ---> 40     for r in results:
#      41         boxes = r.boxes # bounding boxes
#      42         for box in boxes:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\predictor.py:321, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     319 # Preprocess
#     320 with profilers[0]:
# --> 321     im = self.preprocess(im0s)
#     323 # Inference
#     324 with profilers[1]:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\predictor.py:158, in BasePredictor.preprocess(self, im)
#     155     im = np.ascontiguousarray(im)  # contiguous
#     156     im = torch.from_numpy(im)
# --> 158 im = im.to(self.device)
#     159 im = im.half() if self.model.fp16 else im.float()  # uint8 to fp16/32
#     160 if not_tensor:
#
# KeyboardInterrupt:
